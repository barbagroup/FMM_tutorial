# %% [markdown]
# ##Step 1: Direct Summation

# %%
import numpy
import random
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %% [markdown]
# Many physical problems in the world require the evaluation of all pairwise interactions of a large number of particles, and we usually call them N-body problems. A direct simulation of the N-body problem cost $\mathcal{O} \left(N^2 \right)$ operations. In this tutorial, a treecode algorithm is demonstated to reduce the computation cost to $\mathcal{O} \left( N\log N \right)$ on a gravitational N-body problem.
# In the first Ipython Notebook, we will use the most straightforward way to calculate the gravitational field at each point.
#
# To begin with, let's generate a random location for each particle in domain $x$, $y$, $z$ $\in$ $\left[ 0, 1 \right]$. Here we also assume that every particle has the same mass with a sum of 1.

# %%
N = 100                       # number of particles
x = numpy.zeros(N)
y = numpy.zeros(N)
z = numpy.zeros(N)
m = numpy.zeros(N)
phi = numpy.zeros(N)
for i in range(N):
    x[i] = random.random()    # generate the coordinates
    y[i] = random.random()
    z[i] = random.random()
    m[i] = 1.0/N              # assume the same mass

# %% [markdown]
# The spatial distribution of particles should look like this.

# %%
Axes3D(plt.figure()).scatter(x,y,z)
plt.show()

# %% [markdown]
# Direction summation is the closest implementation to a physical problem, where each particle can "feel" the gravitational force due to others in the system. Therefore, the number of interactions scales as $\mathcal{O} \left(N^2 \right)$. The potential at a target point $i$ in the gravitational field can be expressed as:
#
# $$\begin{equation}
# \Phi_i = \sum_{\substack{j=0\\ j \neq i}}^N{\frac{m_j}{r_{ij}}}
# \end{equation}$$
#
# where $m_j$ denotes the mass of source point $j$, and $r_{ij}$ is the distance between target point $i$ and source point $j$.

# %%
# direct summation
def direct_sum(N, x, y, z, m):
    epsilon = 0.001               # avoid zero division
    for i in range(N):
        phi[i] = -m[i]/epsilon    # offset the additional term when i = j
        for j in range(N):
            dx = x[i] - x[j]
            dy = y[i] - y[j]
            dz = z[i] - z[j]
            r = numpy.sqrt(dx**2 + dy**2 + dz**2 + epsilon**2)
            phi[i] += m[j]/r
    return phi

# %%
direct_sum(N, x, y, z, m)
# Out:
# array([ 1.81011501,  1.77050359,  1.86520526,  1.58088953,  1.9276098 ,
#         1.60987663,  1.99318258,  1.78134683,  2.06230132,  1.91745288,
#         1.72661737,  1.49577819,  1.74718505,  2.03847962,  1.91523273,
#         1.87161489,  1.83577985,  1.74385971,  1.75041509,  2.15935246,
#         2.16435217,  1.49884651,  1.47628551,  1.71312581,  1.95603101,
#         1.98816654,  1.62420691,  2.22957675,  1.60965981,  1.7786443 ,
#         1.9207212 ,  2.06914126,  2.09346117,  1.61852104,  1.5586152 ,
#         1.9985642 ,  1.85164272,  2.19952697,  1.76868921,  1.99102015,
#         1.63468709,  1.59345184,  1.713676  ,  1.80553453,  1.78206526,
#         1.86736061,  1.93178462,  1.47958218,  2.07502934,  2.15496895,
#         1.87549485,  1.74439777,  1.5046891 ,  1.88674503,  1.82528337,
#         1.9164701 ,  1.49828   ,  2.01636262,  1.64718929,  2.03660681,
#         1.78190999,  1.79453993,  1.33024105,  1.86928377,  2.16022542,
#         1.43727412,  1.8647056 ,  2.26399729,  1.80912107,  2.07480556,
#         2.14326504,  1.66255353,  2.01105179,  1.8000833 ,  1.70074736,
#         2.2097151 ,  1.63596727,  1.78378343,  1.96853961,  2.05140458,
#         1.62659463,  1.8681441 ,  1.83653738,  1.55706323,  2.03529303,
#         1.64404854,  1.60851714,  1.92023054,  1.74594788,  1.51635339,
#         1.53342614,  1.47337939,  1.57272385,  1.93926598,  1.88058776,
#         1.58096096,  2.13160527,  1.68923109,  1.89396637,  1.48412498])
