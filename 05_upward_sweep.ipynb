# %%
from IPython.core.display import HTML
def css_styling():
    styles = open('./style/fmmstyle.css', 'r').read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 810px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them*/
# div.cell.code_cell {
#     background-color: rgb(256,256,256);
#     border-radius: 0px;
#     padding: 0.5em;
#     margin-left:1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
#     font-family: 'Alegreya Sans' sans-serif;
#     line-height: 140%;
#     font-size: 125%;
#     font-weight: 400;
#     width:600px;
#     margin-left:auto;
#     margin-right:auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Nixie One', serif;
#     font-style:regular;
#     font-weight: 400;
#     font-size: 45pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Nixie One', serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Nixie One', serif;
#     margin-top:16px;
# 	font-size: 22pt;
#     font-weight: 600;
#     margin-bottom: 3px;
#     font-style: regular;
#     color: rgb(102,102,0);
# }
#
# .text_cell_render h4 {    /*Use this for captions*/
#     font-family: 'Nixie One', serif;
#     font-size: 14pt;
#     text-align: center;
#     margin-top: 0em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /*Use this for small titles*/
#     font-family: 'Nixie One', sans-serif;
#     font-weight: 400;
#     font-size: 16pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6 { /*use this for copyright note*/
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono";
#         font-size: 90%;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %% [markdown]
# ## Step 5: Upward Sweep

# %%
import numpy
import random

n = 50           # number of particles
n_crit = 10      # max number of particles in a single cell

root = 0         # index of the first element in cells list
tail = 0         # index of the last element in cells list
curr = 0         # index of the current element in the cells list

cells = []                    # initialize the cells list
x = numpy.zeros(n)            # initialize the coordinates array
y = numpy.zeros(n)
z = numpy.zeros(n)
m = numpy.zeros(n)            # initialize the mass array
for i in range(n):
    x[i] = random.random()    # generate coordinates from 0 to 1
    y[i] = random.random()
    z[i] = random.random()
    m[i] = 1.0/n              # assume the same mass

# %%
class Cell:
    """The class for a cell"""
    def __init__(self):
        self.nleaf = 0        # number of leaves
        self.nchild = 0       # binary counter to keep track of empty cells
        self.leaf = numpy.zeros(n_crit, dtype=numpy.int32)     # array of leaf index
        self.x_c = self.y_c = self.z_c = 0.                    # center of the cell
        self.r = 0.           # radius of the cell
        self.parent = 0       # index of parent cell
        self.child = numpy.zeros(8, dtype=numpy.int32)         # array of child index
        self.multipole = numpy.zeros(10, dtype=numpy.float64)  # multipole array

# %%
def add_child(octant, p):
    """Add a cell to the end of cells list as a child of p, initialize the center and
       radius of the child cell c, and establish mutual reference between child c and
       parent p
    
    Arguments:
      octant:  reference to one of the eight divisions in three dimensions
      p:       parent cell index in cells list
    """
    global tail
    tail += 1
    c = tail
    cells.append(Cell())
    cells[c].r = cells[p].r / 2
    cells[c].x_c = cells[p].x_c + cells[c].r * ((octant & 1) * 2 - 1)
    cells[c].y_c = cells[p].y_c + cells[c].r * ((octant & 2) - 1    )
    cells[c].z_c = cells[p].z_c + cells[c].r * ((octant & 4) / 2 - 1)
    cells[c].parent = p
    cells[p].child[octant] = c
    cells[p].nchild = (cells[p].nchild | (1 << octant))
    print '+++cell {} is created as the child of cell {}, octant = {}'.format(c, p, octant)

# %%
def split_cell(p):
    """Loop in parent p's leafs and reallocate the particles to subcells. If a subcell
       has not been created in that octant, create one using add_child. If the subcell
       c's leaf number exceeds n_crit, split the subcell c recursively.
    
    Arguments: 
    p:       parent cell index in cells list
    """
    print '==start split cell {}=='.format(p)
    for i in range(n_crit):
        l = cells[p].leaf[i]
        octant = (x[l] > cells[p].x_c) + ((y[l] > cells[p].y_c) << 1) \
               + ((z[l] > cells[p].z_c) << 2)
        
        if not cells[p].nchild & (1 << octant):
            add_child(octant, p)
        
        c = cells[p].child[octant]
        cells[c].leaf[cells[c].nleaf] = l
        cells[c].nleaf += 1
        print '>>>particle {} is reallocated in cell {}'.format(i, c)
        if cells[c].nleaf >= n_crit:
            split_cell(c)
    print '==end split cell {}=='.format(p)

# %%
def get_multipole(p):
    """Calculate multipole arrays for all twig cells under cell p. If leaf number of 
       cell p is bigger than n_crit (non-twig), traverse down recursively. Otherwise
       (twig), calculate the multipole arrays for twig cell p.
    
    Arguments:
    p:       cell index in cells list
    """
    if cells[p].nleaf >= n_crit:
        for c in range(8):
            if cells[p].nchild & (1 << c):
                get_multipole(cells[p].child[c])
    else:
        for l in range(cells[p].nleaf):
            j = cells[p].leaf[l]
            dx = cells[p].x_c - x[j]
            dy = cells[p].y_c - y[j]
            dz = cells[p].z_c - z[j]
            cells[p].multipole[0] += m[j]
            cells[p].multipole[1] += m[j] * dx
            cells[p].multipole[2] += m[j] * dy
            cells[p].multipole[3] += m[j] * dz
            cells[p].multipole[4] += m[j] * dx * dx / 2
            cells[p].multipole[5] += m[j] * dy * dy / 2
            cells[p].multipole[6] += m[j] * dz * dz / 2
            cells[p].multipole[7] += m[j] * dx * dy / 2
            cells[p].multipole[8] += m[j] * dy * dz / 2
            cells[p].multipole[9] += m[j] * dz * dx / 2

# %%
def upward_sweep(p, c):
    """Calculate parent cell p's multipole array based on child cell c's multipoles
    
    Arguments:
    p:       parent cell index in cells list
    c:       child cell index in cells list
    """
    dx = cells[p].x_c - cells[c].x_c
    dy = cells[p].y_c - cells[c].y_c
    dz = cells[p].z_c - cells[c].z_c
    cells[p].multipole[0] += cells[c].multipole[0]
    cells[p].multipole[1] += cells[c].multipole[1] + dx * cells[c].multipole[0]
    cells[p].multipole[2] += cells[c].multipole[2] + dy * cells[c].multipole[0]
    cells[p].multipole[3] += cells[c].multipole[3] + dz * cells[c].multipole[0]
    cells[p].multipole[4] += cells[c].multipole[4] + dx * cells[c].multipole[1] \
                                                   + dx * dx * cells[c].multipole[0] / 2
    cells[p].multipole[5] += cells[c].multipole[5] + dy * cells[c].multipole[2] \
                                                   + dy * dy * cells[c].multipole[0] / 2
    cells[p].multipole[6] += cells[c].multipole[6] + dz * cells[c].multipole[3] \
                                                   + dz * dz * cells[c].multipole[0] / 2
    cells[p].multipole[7] += cells[c].multipole[7] + (dx * cells[c].multipole[2] \
                                                   +  dy * cells[c].multipole[1] \
                                                   +  dx * dy * cells[c].multipole[0]) / 2
    cells[p].multipole[8] += cells[c].multipole[8] + (dy * cells[c].multipole[3] \
                                                   +  dz * cells[c].multipole[2] \
                                                   +  dy * dz * cells[c].multipole[0]) / 2
    cells[p].multipole[9] += cells[c].multipole[9] + (dz * cells[c].multipole[1] \
                                                   +  dx * cells[c].multipole[3] \
                                                   +  dz * dx * cells[c].multipole[0]) / 2

# %%
# set root cell
cells.append(Cell())
cells[0].x_c = cells[0].y_c = cells[0].z_c = 0.5
cells[0].r = 0.5

# build tree
for i in range(n):
    curr = 0     # self counter (self)
    while cells[curr].nleaf >= n_crit:
        cells[curr].nleaf += 1
        octant = (x[i] > cells[curr].x_c) + ((y[i] > cells[curr].y_c) << 1) \
               + ((z[i] > cells[curr].z_c) << 2)
        
        if not cells[curr].nchild & (1 << octant):
            add_child(octant, curr)
        curr = cells[curr].child[octant]
    cells[curr].leaf[cells[curr].nleaf] = i
    cells[curr].nleaf += 1
    print 'particle {} is stored in cell {}'.format(i, curr)
    if cells[curr].nleaf >= n_crit:
        split_cell(curr)

# multipole expansion
get_multipole(root)

# upward translation
print 'cell_idx  multipole[0]'
for c in range(tail, root, -1):
    p = cells[c].parent
    upward_sweep(p, c)
    print '{}         {}'.format(c, cells[p].multipole[0])
# Out:
# particle 0 is stored in cell 0
# particle 1 is stored in cell 0
# particle 2 is stored in cell 0
# particle 3 is stored in cell 0
# particle 4 is stored in cell 0
# particle 5 is stored in cell 0
# particle 6 is stored in cell 0
# particle 7 is stored in cell 0
# particle 8 is stored in cell 0
# particle 9 is stored in cell 0
# ==start split cell 0==
# +++cell 1 is created as the child of cell 0, octant = 2
# >>>particle 0 is reallocated in cell 1
# +++cell 2 is created as the child of cell 0, octant = 6
# >>>particle 1 is reallocated in cell 2
# +++cell 3 is created as the child of cell 0, octant = 5
# >>>particle 2 is reallocated in cell 3
# +++cell 4 is created as the child of cell 0, octant = 0
# >>>particle 3 is reallocated in cell 4
# +++cell 5 is created as the child of cell 0, octant = 4
# >>>particle 4 is reallocated in cell 5
# +++cell 6 is created as the child of cell 0, octant = 7
# >>>particle 5 is reallocated in cell 6
# +++cell 7 is created as the child of cell 0, octant = 3
# >>>particle 6 is reallocated in cell 7
# >>>particle 7 is reallocated in cell 7
# >>>particle 8 is reallocated in cell 1
# >>>particle 9 is reallocated in cell 2
# ==end split cell 0==
# particle 10 is stored in cell 6
# particle 11 is stored in cell 2
# particle 12 is stored in cell 7
# +++cell 8 is created as the child of cell 0, octant = 1
# particle 13 is stored in cell 8
# particle 14 is stored in cell 5
# particle 15 is stored in cell 7
# particle 16 is stored in cell 7
# particle 17 is stored in cell 5
# particle 18 is stored in cell 8
# particle 19 is stored in cell 4
# particle 20 is stored in cell 8
# particle 21 is stored in cell 2
# particle 22 is stored in cell 5
# particle 23 is stored in cell 2
# particle 24 is stored in cell 2
# particle 25 is stored in cell 7
# particle 26 is stored in cell 7
# particle 27 is stored in cell 2
# particle 28 is stored in cell 7
# particle 29 is stored in cell 6
# particle 30 is stored in cell 2
# particle 31 is stored in cell 7
# particle 32 is stored in cell 7
# ==start split cell 7==
# +++cell 9 is created as the child of cell 7, octant = 0
# >>>particle 0 is reallocated in cell 9
# +++cell 10 is created as the child of cell 7, octant = 5
# >>>particle 1 is reallocated in cell 10
# >>>particle 2 is reallocated in cell 9
# +++cell 11 is created as the child of cell 7, octant = 1
# >>>particle 3 is reallocated in cell 11
# +++cell 12 is created as the child of cell 7, octant = 4
# >>>particle 4 is reallocated in cell 12
# >>>particle 5 is reallocated in cell 11
# +++cell 13 is created as the child of cell 7, octant = 7
# >>>particle 6 is reallocated in cell 13
# >>>particle 7 is reallocated in cell 13
# >>>particle 8 is reallocated in cell 10
# >>>particle 9 is reallocated in cell 12
# ==end split cell 7==
# particle 33 is stored in cell 2
# particle 34 is stored in cell 3
# particle 35 is stored in cell 6
# particle 36 is stored in cell 4
# particle 37 is stored in cell 8
# particle 38 is stored in cell 2
# ==start split cell 2==
# +++cell 14 is created as the child of cell 2, octant = 7
# >>>particle 0 is reallocated in cell 14
# +++cell 15 is created as the child of cell 2, octant = 3
# >>>particle 1 is reallocated in cell 15
# +++cell 16 is created as the child of cell 2, octant = 0
# >>>particle 2 is reallocated in cell 16
# >>>particle 3 is reallocated in cell 15
# +++cell 17 is created as the child of cell 2, octant = 1
# >>>particle 4 is reallocated in cell 17
# +++cell 18 is created as the child of cell 2, octant = 2
# >>>particle 5 is reallocated in cell 18
# >>>particle 6 is reallocated in cell 16
# +++cell 19 is created as the child of cell 2, octant = 5
# >>>particle 7 is reallocated in cell 19
# >>>particle 8 is reallocated in cell 17
# +++cell 20 is created as the child of cell 2, octant = 6
# >>>particle 9 is reallocated in cell 20
# ==end split cell 2==
# particle 39 is stored in cell 6
# particle 40 is stored in cell 4
# particle 41 is stored in cell 8
# particle 42 is stored in cell 1
# particle 43 is stored in cell 19
# particle 44 is stored in cell 3
# particle 45 is stored in cell 3
# particle 46 is stored in cell 11
# particle 47 is stored in cell 13
# +++cell 21 is created as the child of cell 7, octant = 6
# particle 48 is stored in cell 21
# particle 49 is stored in cell 1
# cell_idx  multipole[0]
# 21         0.02
# 20         0.02
# 19         0.06
# 18         0.08
# 17         0.12
# 16         0.16
# 15         0.2
# 14         0.22
# 13         0.08
# 12         0.12
# 11         0.18
# 10         0.22
# 9         0.26
# 8         0.1
# 7         0.36
# 6         0.46
# 5         0.54
# 4         0.62
# 3         0.7
# 2         0.92
# 1         1.0
