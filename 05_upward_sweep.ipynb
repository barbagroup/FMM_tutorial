# %% [markdown]
# # Step 5: Upward Sweep

# %%
import numpy
import random
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

NCRIT = 10             # max number of particles in a single cell
N = 50                 # number of particles
CELLS = []             # initialize the list that stores cells
child_idx = 0          # global child counter
parent_idx = 0         # global parent counter
cells = 0              # cells counter in traverse
leafs = 0              # leafs counter in traverse

x = numpy.zeros(N)
y = numpy.zeros(N)
z = numpy.zeros(N)
m = numpy.zeros(N)
for i in range(N):
    x[i] = random.random()    # coordinate domain from 0 to 1
    y[i] = random.random()
    z[i] = random.random()
    m[i] = 1.0/N

# %%
class cell:
    def __init__(self):
        self.nleaf = 0      # number of leaves (counter)
        self.nchild = 0     # keep track of empty cells (binary counter)
        self.leaf = numpy.zeros(NCRIT, dtype=numpy.int32)  # pointer to leaves
        self.x_c = self.y_c = self.z_c = 0.                # center of the cell
        self.r = 0.         # radius of the cell
        self.parent = 0     # pointer to parent cell
        self.child = numpy.zeros(8, dtype=numpy.int32)     # pointer to child cells
        self.multipole = numpy.zeros(10, dtype=numpy.float64)    # multipole array

# %%
def add_child(octant, p, c):
    """
    ---Parameters---
    octant:  reference to one of the eight divisions in 3D
    p:       parent cell index in CELL list
    c:       child cell index in CELL list
    """
    global child_idx
    child_idx += 1
    c = child_idx
    CELLS.append(cell())
    CELLS[c].r = CELLS[p].r / 2
    CELLS[c].x_c = CELLS[p].x_c + CELLS[c].r * ((octant & 1) * 2 - 1)
    CELLS[c].y_c = CELLS[p].y_c + CELLS[c].r * ((octant & 2) - 1    )
    CELLS[c].z_c = CELLS[p].z_c + CELLS[c].r * ((octant & 4) / 2 - 1)
    CELLS[c].parent = p
    CELLS[p].child[octant] = c
    CELLS[p].nchild = (CELLS[p].nchild | (1 << octant))
    print '+++cell {} is created as the child of cell {}, octant = {}'.format(c, p, octant)

# %%
def split_cell(x, y, z, p, c):
    """
    ---Parameters---
    x, y, z: particle location arrays
    p:       parent cell index in CELL list
    c:       child cell index in CELL list
    """
    print '==start split cell {}=='.format(p)
    for i in range(NCRIT):
        l = CELLS[p].leaf[i]            # l: particle index of the parent's leafs
        octant = (x[l] > CELLS[p].x_c) + ((y[l] > CELLS[p].y_c) << 1) + ((z[l] > CELLS[p].z_c) << 2)
        if not (CELLS[p].nchild & (1 << octant)):
            add_child(octant, p, c)
        cc = CELLS[p].child[octant]     # cc: index of the current child of parent p
        CELLS[cc].leaf[CELLS[cc].nleaf] = l
        CELLS[cc].nleaf += 1
        print '>>>particle {} is reallocated in cell {}'.format(i, cc)
        # if all the particles go into a certain child, split this child recursively
        if CELLS[cc].nleaf >= NCRIT:
            split_cell(x, y, z, cc, child_idx)
    print '==end split cell {}=='.format(p)

# %%
def get_multipole(p, x, y, z, m):
    if (CELLS[p].nleaf >= NCRIT):
        for c in range(8):
            if (CELLS[p].nchild & (1 << c)):
                get_multipole(CELLS[p].child[c], x, y, z, m)
    else:
        for l in range(CELLS[p].nleaf):
            j = CELLS[p].leaf[l]
            dx = CELLS[p].x_c - x[j]
            dy = CELLS[p].y_c - y[j]
            dz = CELLS[p].z_c - z[j]
            CELLS[p].multipole[0] += m[j]
            CELLS[p].multipole[1] += m[j] * dx
            CELLS[p].multipole[2] += m[j] * dy
            CELLS[p].multipole[3] += m[j] * dz
            CELLS[p].multipole[4] += m[j] * dx**2 / 2
            CELLS[p].multipole[5] += m[j] * dy**2 / 2
            CELLS[p].multipole[6] += m[j] * dz**2 / 2
            CELLS[p].multipole[7] += m[j] * dx * dy / 2
            CELLS[p].multipole[8] += m[j] * dy * dz / 2
            CELLS[p].multipole[9] += m[j] * dz * dx / 2

# %%
def upward_sweep(p, c):
    dx = CELLS[p].x_c - CELLS[c].x_c
    dy = CELLS[p].y_c - CELLS[c].y_c
    dz = CELLS[p].z_c - CELLS[c].z_c
    CELLS[p].multipole[0] += CELLS[c].multipole[0]
    CELLS[p].multipole[1] += CELLS[c].multipole[1] + dx * CELLS[c].multipole[0]
    CELLS[p].multipole[2] += CELLS[c].multipole[2] + dy * CELLS[c].multipole[0]
    CELLS[p].multipole[3] += CELLS[c].multipole[3] + dz * CELLS[c].multipole[0]
    CELLS[p].multipole[4] += CELLS[c].multipole[4] + dx * CELLS[c].multipole[1] + dx**2 * CELLS[c].multipole[0] / 2
    CELLS[p].multipole[5] += CELLS[c].multipole[5] + dy * CELLS[c].multipole[2] + dy**2 * CELLS[c].multipole[0] / 2
    CELLS[p].multipole[6] += CELLS[c].multipole[6] + dz * CELLS[c].multipole[3] + dz**2 * CELLS[c].multipole[0] / 2
    CELLS[p].multipole[7] += CELLS[c].multipole[7] + (dx * CELLS[c].multipole[2] + dy * CELLS[c].multipole[1] + dx * dy * CELLS[c].multipole[0]) / 2
    CELLS[p].multipole[8] += CELLS[c].multipole[8] + (dy * CELLS[c].multipole[3] + dz * CELLS[c].multipole[2] + dy * dz * CELLS[c].multipole[0]) / 2
    CELLS[p].multipole[9] += CELLS[c].multipole[9] + (dz * CELLS[c].multipole[1] + dx * CELLS[c].multipole[3] + dz * dx * CELLS[c].multipole[0]) / 2

# %%
# set root cell
CELLS.append(cell())
CELLS[0].x_c = CELLS[0].y_c = CELLS[0].z_c = 0.5
CELLS[0].r = 0.5

# build tree
for i in range(N):
    parent_idx = 0     # self counter (self)
    while CELLS[parent_idx].nleaf >= NCRIT:
        CELLS[parent_idx].nleaf += 1
        octant = (x[i] > CELLS[parent_idx].x_c) + ((y[i] > CELLS[parent_idx].y_c) << 1) + ((z[i] > CELLS[parent_idx].z_c) << 2)
        if not (CELLS[parent_idx].nchild & (1 << octant)):
            add_child(octant, parent_idx, child_idx)
        parent_idx = CELLS[parent_idx].child[octant]
    CELLS[parent_idx].leaf[CELLS[parent_idx].nleaf] = i
    CELLS[parent_idx].nleaf += 1
    print 'particle {} is stored in cell {}'.format(i, parent_idx)
    if (CELLS[parent_idx].nleaf >= NCRIT):
        split_cell(x, y, z, parent_idx, child_idx)

# multipole expansion
get_multipole(0, x, y, z, m)

# upward translation
for c in range(child_idx, 0, -1):
    p = CELLS[c].parent
    upward_sweep(p, c)
    print '{} {}'.format(c, CELLS[p].multipole[0])
# Out:
# particle 0 is stored in cell 0
# particle 1 is stored in cell 0
# particle 2 is stored in cell 0
# particle 3 is stored in cell 0
# particle 4 is stored in cell 0
# particle 5 is stored in cell 0
# particle 6 is stored in cell 0
# particle 7 is stored in cell 0
# particle 8 is stored in cell 0
# particle 9 is stored in cell 0
# ==start split cell 0==
# +++cell 1 is created as the child of cell 0, octant = 3
# >>>particle 0 is reallocated in cell 1
# +++cell 2 is created as the child of cell 0, octant = 7
# >>>particle 1 is reallocated in cell 2
# +++cell 3 is created as the child of cell 0, octant = 2
# >>>particle 2 is reallocated in cell 3
# +++cell 4 is created as the child of cell 0, octant = 0
# >>>particle 3 is reallocated in cell 4
# >>>particle 4 is reallocated in cell 1
# +++cell 5 is created as the child of cell 0, octant = 5
# >>>particle 5 is reallocated in cell 5
# +++cell 6 is created as the child of cell 0, octant = 6
# >>>particle 6 is reallocated in cell 6
# >>>particle 7 is reallocated in cell 3
# +++cell 7 is created as the child of cell 0, octant = 1
# >>>particle 8 is reallocated in cell 7
# >>>particle 9 is reallocated in cell 1
# ==end split cell 0==
# particle 10 is stored in cell 4
# particle 11 is stored in cell 1
# particle 12 is stored in cell 4
# particle 13 is stored in cell 6
# particle 14 is stored in cell 4
# particle 15 is stored in cell 6
# particle 16 is stored in cell 1
# particle 17 is stored in cell 1
# particle 18 is stored in cell 3
# particle 19 is stored in cell 2
# particle 20 is stored in cell 4
# particle 21 is stored in cell 7
# particle 22 is stored in cell 5
# +++cell 8 is created as the child of cell 0, octant = 4
# particle 23 is stored in cell 8
# particle 24 is stored in cell 1
# particle 25 is stored in cell 3
# particle 26 is stored in cell 6
# particle 27 is stored in cell 8
# particle 28 is stored in cell 6
# particle 29 is stored in cell 1
# particle 30 is stored in cell 3
# particle 31 is stored in cell 4
# particle 32 is stored in cell 3
# particle 33 is stored in cell 5
# particle 34 is stored in cell 1
# particle 35 is stored in cell 8
# particle 36 is stored in cell 5
# particle 37 is stored in cell 1
# ==start split cell 1==
# +++cell 9 is created as the child of cell 1, octant = 3
# >>>particle 0 is reallocated in cell 9
# +++cell 10 is created as the child of cell 1, octant = 7
# >>>particle 1 is reallocated in cell 10
# +++cell 11 is created as the child of cell 1, octant = 4
# >>>particle 2 is reallocated in cell 11
# +++cell 12 is created as the child of cell 1, octant = 0
# >>>particle 3 is reallocated in cell 12
# >>>particle 4 is reallocated in cell 9
# +++cell 13 is created as the child of cell 1, octant = 6
# >>>particle 5 is reallocated in cell 13
# +++cell 14 is created as the child of cell 1, octant = 2
# >>>particle 6 is reallocated in cell 14
# >>>particle 7 is reallocated in cell 10
# >>>particle 8 is reallocated in cell 12
# +++cell 15 is created as the child of cell 1, octant = 1
# >>>particle 9 is reallocated in cell 15
# ==end split cell 1==
# particle 38 is stored in cell 4
# particle 39 is stored in cell 5
# particle 40 is stored in cell 11
# particle 41 is stored in cell 8
# particle 42 is stored in cell 2
# particle 43 is stored in cell 2
# particle 44 is stored in cell 3
# particle 45 is stored in cell 3
# particle 46 is stored in cell 8
# particle 47 is stored in cell 6
# particle 48 is stored in cell 4
# particle 49 is stored in cell 12
# 15 0.02
# 14 0.04
# 13 0.06
# 12 0.12
# 11 0.16
# 10 0.2
# 9 0.24
# 8 0.1
# 7 0.14
# 6 0.26
# 5 0.36
# 4 0.52
# 3 0.68
# 2 0.76
# 1 1.0
